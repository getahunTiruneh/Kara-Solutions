# %% [markdown]
# ## Object detaction using YOLOv5

# %% [markdown]
# ### Import Required Libraries and Set Up Environment

# %%
# Import necessary libraries
import os
import sys
import torch
import cv2
import pandas as pd
from datetime import datetime

# Set the current directory
current_dir = os.getcwd()
# Append the parent directory to sys.path
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)

# ignore warrnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Import YOLO Object Detection Functions

# %%
# Import YOLO object detection functions from the custom scripts
from scripts.YOLO_object_detector import load_yolo_model, process_images, save_detections_to_csv

# %% [markdown]
# #### Load YOLO Model and Set Image Paths

# %%
# Load the YOLO model for object detection
model = load_yolo_model()

# Define the folder containing images and the output folder for detection results
image_folder = '../data/photos'
output_folder = '../data/detaction_results'
# Out:
# Using cache found in C:\Users\Getahun/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-10-12 Python-3.12.6 torch-2.4.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %% [markdown]
# #### Process Images for Object Detection and Save Results

# %%
# Process the images in the specified folder for object detection
detection_data = process_images(model, image_folder, output_folder)

# Save the detection results to a CSV file in the output folder
save_detections_to_csv(detection_data, output_folder)
# Out:
# WARNING  NMS time limit 0.550s exceeded
# Detected toilet with confidence 0.63
# Detected sports ball with confidence 0.43
# Detected sports ball with confidence 0.42
# Detected sports ball with confidence 0.28
# Detected bottle with confidence 0.65
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.37
# Detected remote with confidence 0.34
# Detected bottle with confidence 0.33
# Detected bottle with confidence 0.29
# Detected bottle with confidence 0.29
# Detected refrigerator with confidence 0.27
# Detected bottle with confidence 0.27
# Detected bottle with confidence 0.26
# Detected person with confidence 0.89
# Detected person with confidence 0.87
# Detected person with confidence 0.51
# Detected chair with confidence 0.26
# Detected sports ball with confidence 0.68
# Detected sports ball with confidence 0.58
# Detected sports ball with confidence 0.53
# Detected sports ball with confidence 0.48
# Detected sports ball with confidence 0.45
# Detected sports ball with confidence 0.45
# Detected sports ball with confidence 0.42
# Detected sports ball with confidence 0.34
# Detected sports ball with confidence 0.30
# Detected cake with confidence 0.28
# Detected sports ball with confidence 0.26
# Detected person with confidence 0.89
# Detected person with confidence 0.87
# Detected person with confidence 0.51
# Detected chair with confidence 0.26
# Detected cell phone with confidence 0.76
# Detected book with confidence 0.46
# Detected cell phone with confidence 0.55
# Detected person with confidence 0.27
# Detected cup with confidence 0.48
# Detected person with confidence 0.73
# Detected frisbee with confidence 0.38
# Detected laptop with confidence 0.28
# Detected clock with confidence 0.51
# Detected person with confidence 0.28
# Detected bottle with confidence 0.65
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.36
# Detected remote with confidence 0.35
# Detected bottle with confidence 0.33
# Detected bottle with confidence 0.30
# Detected bottle with confidence 0.30
# Detected refrigerator with confidence 0.27
# Detected bottle with confidence 0.27
# Detected bottle with confidence 0.25
# Detected baseball bat with confidence 0.32
# Detected baseball bat with confidence 0.25
# Detected mouse with confidence 0.90
# Detected mouse with confidence 0.88
# Detected mouse with confidence 0.84
# Detected mouse with confidence 0.75
# Detected mouse with confidence 0.69
# Detected mouse with confidence 0.54
# Detected mouse with confidence 0.47
# Detected mouse with confidence 0.45
# Detected person with confidence 0.56
# Detected person with confidence 0.45
# Detected person with confidence 0.45
# Detected person with confidence 0.38
# Detected person with confidence 0.34
# Detected remote with confidence 0.77
# Detected remote with confidence 0.48
# Detected person with confidence 0.59
# Detected keyboard with confidence 0.36
# Detected cell phone with confidence 0.30
# Detected cell phone with confidence 0.94
# Detected person with confidence 0.50
# Detected knife with confidence 0.29
# Detected remote with confidence 0.25
# Detected person with confidence 0.75
# Detected clock with confidence 0.35
# Detected cup with confidence 0.49
# Detected mouse with confidence 0.34
# Detected horse with confidence 0.86
# Detected person with confidence 0.73
# Detected person with confidence 0.66
# Detected person with confidence 0.61
# Detected person with confidence 0.61
# Detected sports ball with confidence 0.68
# Detected sports ball with confidence 0.57
# Detected sports ball with confidence 0.56
# Detected sports ball with confidence 0.55
# Detected sports ball with confidence 0.48
# Detected sports ball with confidence 0.47
# Detected sports ball with confidence 0.44
# Detected sports ball with confidence 0.38
# Detected sports ball with confidence 0.34
# Detected cake with confidence 0.28
# Detected sports ball with confidence 0.28
# Detected sports ball with confidence 0.26
# Detected bottle with confidence 0.44
# Detected clock with confidence 0.49
# Detected bed with confidence 0.27
# Detected chair with confidence 0.26
# Detected stop sign with confidence 0.73
# Detected potted plant with confidence 0.84
# Detected person with confidence 0.71
# Detected person with confidence 0.91
# Detected person with confidence 0.83
# Detected sports ball with confidence 0.25
# Detected person with confidence 0.48
# Detected person with confidence 0.50
# Detected bottle with confidence 0.85
# Detected bottle with confidence 0.75
# Detected bottle with confidence 0.69
# Detected bottle with confidence 0.27
# Detected clock with confidence 0.42
# Detected donut with confidence 0.29
# Detected person with confidence 0.92
# Detected chair with confidence 0.64
# Detected bottle with confidence 0.83
# Detected bottle with confidence 0.78
# Detected bottle with confidence 0.73
# Detected bottle with confidence 0.58
# Detected bottle with confidence 0.52
# Detected bottle with confidence 0.86
# Detected bottle with confidence 0.72
# Detected bottle with confidence 0.66
# Detected mouse with confidence 0.65
# Detected person with confidence 0.79
# Detected frisbee with confidence 0.76
# Detected frisbee with confidence 0.66
# Detected banana with confidence 0.52
# Detected banana with confidence 0.48
# Detected banana with confidence 0.42
# Detected banana with confidence 0.37
# Detected banana with confidence 0.26
# Detected banana with confidence 0.26
# Detected sports ball with confidence 0.68
# Detected sports ball with confidence 0.58
# Detected sports ball with confidence 0.53
# Detected sports ball with confidence 0.48
# Detected sports ball with confidence 0.45
# Detected sports ball with confidence 0.45
# Detected sports ball with confidence 0.42
# Detected sports ball with confidence 0.34
# Detected sports ball with confidence 0.30
# Detected cake with confidence 0.28
# Detected sports ball with confidence 0.26
# Detected person with confidence 0.53
# Detected person with confidence 0.87
# Detected zebra with confidence 0.41
# Detected sports ball with confidence 0.35
# Detected person with confidence 0.66
# Detected vase with confidence 0.63
# Detected vase with confidence 0.59
# Detected cake with confidence 0.30
# Detected person with confidence 0.35
# Detected person with confidence 0.26
# Detected sports ball with confidence 0.32
# Error processing lobelia4cosmetics_10583.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10584.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10585.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10586.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10587.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10588.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10589.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10590.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10591.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10592.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10593.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10594.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10595.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10596.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10597.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10598.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10599.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10600.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10601.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10602.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10603.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10604.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10605.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10606.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10607.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10608.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10609.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10610.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10611.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10612.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10613.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10614.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10615.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10616.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10617.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10618.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10619.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10620.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10621.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10622.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10623.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10624.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10625.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10626.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10627.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10628.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10629.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10630.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10631.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10632.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10633.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Error processing lobelia4cosmetics_10634.jpg: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:813: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
#
# Detected vase with confidence 0.28
# Detected book with confidence 0.32
# Detected bottle with confidence 0.55
# Detected cup with confidence 0.30
# Detected book with confidence 0.65
# Detected book with confidence 0.54
# Detected person with confidence 0.29
# Detected book with confidence 0.26
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.38
# Detected person with confidence 0.55
# Detected parking meter with confidence 0.62
# Detected bottle with confidence 0.46
# Detected bottle with confidence 0.33
# Detected person with confidence 0.53
# Detected person with confidence 0.91
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.44
# Detected bottle with confidence 0.83
# Detected person with confidence 0.90
# Detected person with confidence 0.49
# Detected bottle with confidence 0.50
# Detected bottle with confidence 0.40
# Detected cup with confidence 0.37
# Detected cup with confidence 0.40
# Detected bottle with confidence 0.42
# Detected person with confidence 0.93
# Detected person with confidence 0.47
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected bottle with confidence 0.45
# Detected vase with confidence 0.28
# Detected book with confidence 0.32
# Detected parking meter with confidence 0.62
# Detected cup with confidence 0.30
# Detected book with confidence 0.70
# Detected book with confidence 0.53
# Detected book with confidence 0.36
# Detected bottle with confidence 0.59
# Detected bottle with confidence 0.40
# Detected bottle with confidence 0.82
# Detected bottle with confidence 0.64
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.39
# Detected tie with confidence 0.32
# Detected bottle with confidence 0.55
# Detected bottle with confidence 0.78
# Detected bottle with confidence 0.55
# Detected bottle with confidence 0.29
# Detected bottle with confidence 0.65
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.31
# Detected vase with confidence 0.28
# Detected bottle with confidence 0.79
# Detected bottle with confidence 0.52
# Detected bottle with confidence 0.43
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.38
# Detected bottle with confidence 0.55
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected banana with confidence 0.60
# Detected bottle with confidence 0.55
# Detected cup with confidence 0.30
# Detected book with confidence 0.65
# Detected book with confidence 0.54
# Detected person with confidence 0.29
# Detected book with confidence 0.26
# Detected parking meter with confidence 0.35
# Detected bottle with confidence 0.65
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.31
# Detected tie with confidence 0.37
# Detected remote with confidence 0.29
# Detected vase with confidence 0.28
# Detected book with confidence 0.32
# Detected cup with confidence 0.30
# Detected person with confidence 0.55
# Detected parking meter with confidence 0.62
# Detected person with confidence 0.85
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected parking meter with confidence 0.29
# Detected person with confidence 0.84
# Detected bottle with confidence 0.46
# Detected bottle with confidence 0.33
# Detected person with confidence 0.53
# Detected person with confidence 0.91
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.44
# Detected bottle with confidence 0.83
# Detected person with confidence 0.90
# Detected person with confidence 0.49
# Detected bottle with confidence 0.50
# Detected bottle with confidence 0.40
# Detected cup with confidence 0.37
# Detected cup with confidence 0.40
# Detected bottle with confidence 0.42
# Detected person with confidence 0.93
# Detected person with confidence 0.47
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected bottle with confidence 0.45
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected bottle with confidence 0.55
# Detected vase with confidence 0.28
# Detected book with confidence 0.32
# Detected cup with confidence 0.30
# Detected book with confidence 0.70
# Detected book with confidence 0.53
# Detected book with confidence 0.36
# Detected tie with confidence 0.32
# Detected bottle with confidence 0.55
# Detected bottle with confidence 0.78
# Detected bottle with confidence 0.29
# Detected person with confidence 0.85
# Detected person with confidence 0.55
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected bottle with confidence 0.27
# Detected bottle with confidence 0.79
# Detected bottle with confidence 0.52
# Detected bottle with confidence 0.43
# Detected bottle with confidence 0.31
# Detected book with confidence 0.27
# Detected book with confidence 0.70
# Detected book with confidence 0.53
# Detected book with confidence 0.36
# Detected bottle with confidence 0.59
# Detected bottle with confidence 0.40
# Detected bottle with confidence 0.82
# Detected bottle with confidence 0.64
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.39
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected vase with confidence 0.28
# Detected book with confidence 0.32
# Detected person with confidence 0.85
# Detected book with confidence 0.32
# Detected cup with confidence 0.30
# Detected bottle with confidence 0.55
# Detected person with confidence 0.86
# Detected bottle with confidence 0.65
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.31
# Detected vase with confidence 0.28
# Detected cup with confidence 0.30
# Detected person with confidence 0.85
# Detected bottle with confidence 0.65
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.31
# Detected vase with confidence 0.28
# Detected book with confidence 0.32
# Detected cup with confidence 0.30
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected person with confidence 0.55
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.38
# Detected person with confidence 0.55
# Detected bottle with confidence 0.55
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected person with confidence 0.85
# Detected bottle with confidence 0.31
# Detected book with confidence 0.27
# Detected bottle with confidence 0.55
# Detected person with confidence 0.86
# Detected bottle with confidence 0.65
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.31
# Detected vase with confidence 0.28
# Detected cup with confidence 0.30
# Detected cup with confidence 0.75
# Detected vase with confidence 0.28
# Detected book with confidence 0.32
# Detected book with confidence 0.70
# Detected book with confidence 0.53
# Detected book with confidence 0.36
# Detected bottle with confidence 0.59
# Detected bottle with confidence 0.40
# Detected bottle with confidence 0.82
# Detected bottle with confidence 0.64
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.55
# Detected bottle with confidence 0.55
# Detected bottle with confidence 0.29
# Detected parking meter with confidence 0.29
# Detected person with confidence 0.84
# Detected bottle with confidence 0.46
# Detected bottle with confidence 0.29
# Detected person with confidence 0.86
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.38
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected person with confidence 0.85
# Detected microwave with confidence 0.26
# Detected bottle with confidence 0.55
# Detected person with confidence 0.86
# Detected vase with confidence 0.28
# Detected cup with confidence 0.30
# Detected cup with confidence 0.75
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.50
# Detected bottle with confidence 0.40
# Detected cup with confidence 0.37
# Detected person with confidence 0.93
# Detected person with confidence 0.47
# Detected tie with confidence 0.32
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected person with confidence 0.55
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.38
# Detected bottle with confidence 0.55
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected microwave with confidence 0.26
# Detected person with confidence 0.85
# Detected bottle with confidence 0.55
# Detected person with confidence 0.86
# Detected vase with confidence 0.28
# Detected cup with confidence 0.30
# Detected cup with confidence 0.75
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected microwave with confidence 0.26
# Detected person with confidence 0.85
# Detected bottle with confidence 0.55
# Detected bottle with confidence 0.55
# Detected bottle with confidence 0.29
# Detected parking meter with confidence 0.29
# Detected person with confidence 0.84
# Detected clock with confidence 0.65
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.50
# Detected bottle with confidence 0.40
# Detected cup with confidence 0.37
# Detected person with confidence 0.93
# Detected person with confidence 0.47
# Detected tie with confidence 0.32
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected person with confidence 0.55
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected cup with confidence 0.75
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.38
# Detected person with confidence 0.55
# Detected bottle with confidence 0.55
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected person with confidence 0.55
# Detected person with confidence 0.86
# Detected bottle with confidence 0.65
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.31
# Detected vase with confidence 0.28
# Detected cup with confidence 0.30
# Detected cup with confidence 0.75
# Detected bottle with confidence 0.46
# Detected person with confidence 0.53
# Detected person with confidence 0.91
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.44
# Detected bottle with confidence 0.83
# Detected person with confidence 0.90
# Detected person with confidence 0.49
# Detected bottle with confidence 0.50
# Detected bottle with confidence 0.40
# Detected cup with confidence 0.37
# Detected cup with confidence 0.40
# Detected bottle with confidence 0.42
# Detected person with confidence 0.93
# Detected person with confidence 0.47
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected bottle with confidence 0.45
# Detected bottle with confidence 0.55
# Detected vase with confidence 0.28
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected microwave with confidence 0.26
# Detected person with confidence 0.85
# Detected bottle with confidence 0.55
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected bottle with confidence 0.55
# Detected cup with confidence 0.30
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected person with confidence 0.86
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.38
# Detected cup with confidence 0.39
# Detected person with confidence 0.55
# Detected parking meter with confidence 0.62
# Detected bottle with confidence 0.55
# Detected cup with confidence 0.30
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected person with confidence 0.86
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.38
# Detected cup with confidence 0.39
# Detected person with confidence 0.55
# Detected parking meter with confidence 0.62
# Detected person with confidence 0.85
# Detected bottle with confidence 0.55
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected person with confidence 0.86
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.38
# Detected vase with confidence 0.28
# Detected cup with confidence 0.75
# Detected person with confidence 0.55
# Detected cup with confidence 0.39
# Detected person with confidence 0.85
# Detected bottle with confidence 0.29
# Detected person with confidence 0.84
# Detected clock with confidence 0.65
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.50
# Detected bottle with confidence 0.40
# Detected cup with confidence 0.37
# Detected person with confidence 0.93
# Detected person with confidence 0.47
# Detected tie with confidence 0.32
# Detected bottle with confidence 0.65
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.31
# Detected vase with confidence 0.28
# Detected cup with confidence 0.30
# Detected cup with confidence 0.75
# Detected cup with confidence 0.30
# Detected person with confidence 0.55
# Detected cup with confidence 0.39
# Detected person with confidence 0.85
# Detected person with confidence 0.86
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.38
# Detected person with confidence 0.86
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected cup with confidence 0.75
# Detected vase with confidence 0.28
# Detected bottle with confidence 0.55
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected cup with confidence 0.75
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected person with confidence 0.55
# Detected clock with confidence 0.50
# Detected clock with confidence 0.29
# Detected cup with confidence 0.39
# Detected person with confidence 0.85
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected cup with confidence 0.75
# Detected person with confidence 0.86
# Detected bottle with confidence 0.65
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.31
# Detected vase with confidence 0.28
# Detected cup with confidence 0.30
# Detected bottle with confidence 0.46
# Detected person with confidence 0.53
# Detected person with confidence 0.91
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.39
# Detected person with confidence 0.90
# Detected person with confidence 0.49
# Detected bottle with confidence 0.50
# Detected bottle with confidence 0.40
# Detected cup with confidence 0.75
# Detected book with confidence 0.70
# Detected book with confidence 0.53
# Detected book with confidence 0.36
# Detected bottle with confidence 0.59
# Detected bottle with confidence 0.40
# Detected bottle with confidence 0.82
# Detected bottle with confidence 0.64
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.39
# Detected person with confidence 0.85
# Detected cup with confidence 0.75
# Detected cup with confidence 0.39
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected person with confidence 0.86
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.38
# Detected vase with confidence 0.28
# Detected cup with confidence 0.39
# Detected cup with confidence 0.39
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected person with confidence 0.86
# Detected person with confidence 0.85
# Detected vase with confidence 0.28
# Detected bottle with confidence 0.55
# Detected stop sign with confidence 0.32
# Detected stop sign with confidence 0.73
# Detected person with confidence 0.55
# Detected clock with confidence 0.65
# Detected bottle with confidence 0.29
# Detected person with confidence 0.84
# Detected cup with confidence 0.75
# Detected person with confidence 0.85
# Detected person with confidence 0.86
# Detected bottle with confidence 0.65
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.31
# Detected clock with confidence 0.65
# Detected person with confidence 0.85
# Detected vase with confidence 0.28
# Detected cup with confidence 0.30
# Detected bottle with confidence 0.46
# Detected cup with confidence 0.30
# Detected person with confidence 0.55
# Detected cup with confidence 0.37
# Detected cup with confidence 0.30
# Detected cup with confidence 0.75
# Detected person with confidence 0.85
# Detected person with confidence 0.55
# Detected parking meter with confidence 0.62
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected bottle with confidence 0.55
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.38
# Detected person with confidence 0.55
# Detected clock with confidence 0.65
# Detected person with confidence 0.85
# Detected stop sign with confidence 0.32
# Detected cup with confidence 0.75
# Detected person with confidence 0.55
# Detected parking meter with confidence 0.62
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected bottle with confidence 0.55
# Detected person with confidence 0.85
# Detected clock with confidence 0.65
# Detected person with confidence 0.85
# Detected person with confidence 0.55
# Detected parking meter with confidence 0.29
# Detected bottle with confidence 0.29
# Detected cup with confidence 0.30
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.38
# Detected person with confidence 0.86
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected vase with confidence 0.28
# Detected bottle with confidence 0.29
# Detected bottle with confidence 0.50
# Detected bottle with confidence 0.40
# Detected bottle with confidence 0.46
# Detected person with confidence 0.55
# Detected cup with confidence 0.75
# Detected person with confidence 0.85
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected bottle with confidence 0.65
# Detected bottle with confidence 0.39
# Detected bottle with confidence 0.31
# Detected bottle with confidence 0.55
# Detected clock with confidence 0.65
# Detected cup with confidence 0.75
# Detected bottle with confidence 0.58
# Detected bottle with confidence 0.31
# Detected bowl with confidence 0.67
# Detected vase with confidence 0.25
# Detected bowl with confidence 0.48
# Detected cup with confidence 0.75
# Detected person with confidence 0.85
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.75
# Detected person with confidence 0.72
# Detected bottle with confidence 0.61
# Detected person with confidence 0.59
# Detected person with confidence 0.29
# Detected bottle with confidence 0.54
# Detected cup with confidence 0.75
# Detected person with confidence 0.85
# Detected cup with confidence 0.30
# Detected cup with confidence 0.30
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected person with confidence 0.86
# Detected person with confidence 0.55
# Detected parking meter with confidence 0.62
# Detected cup with confidence 0.39
# Detected person with confidence 0.85
# Detected bottle with confidence 0.55
# Detected bottle with confidence 0.58
# Detected bottle with confidence 0.31
# Detected bowl with confidence 0.67
# Detected vase with confidence 0.25
# Detected cup with confidence 0.75
# Detected bowl with confidence 0.48
# Detected bottle with confidence 0.29
# Detected person with confidence 0.84
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.39
# Detected cup with confidence 0.37
# Detected cup with confidence 0.30
# Detected cup with confidence 0.39
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.86
# Detected clock with confidence 0.65
# Detected person with confidence 0.85
# Detected bowl with confidence 0.67
# Detected vase with confidence 0.25
# Detected bottle with confidence 0.55
# Detected vase with confidence 0.28
# Detected bottle with confidence 0.57
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.52
# Detected toilet with confidence 0.49
# Detected bottle with confidence 0.47
# Detected bottle with confidence 0.39
# Detected suitcase with confidence 0.31
# Detected toilet with confidence 0.28
# Detected cup with confidence 0.39
# Detected book with confidence 0.65
# Detected book with confidence 0.43
# Detected person with confidence 0.31
# Detected bottle with confidence 0.37
# Detected bottle with confidence 0.47
# Detected person with confidence 0.86
# Detected clock with confidence 0.65
# Detected person with confidence 0.85
# Detected bowl with confidence 0.67
# Detected bottle with confidence 0.50
# Detected bottle with confidence 0.40
# Detected bottle with confidence 0.56
# Detected bottle with confidence 0.39
# Detected person with confidence 0.55
# Error processing lobelia4cosmetics_998.jpg: 'NoneType' object has no attribute 'shape'
# Detections saved to CSV and images saved in results folder.

# %% [markdown]
# #### Load Detection Results from CSV

# %%
# Load the detection results from the CSV file into a Pandas DataFrame
df = pd.read_csv('../data/detaction_results/detections.csv')

# %%
df.head()
# Out:
#          image_name  confidence_score   class_name  \
# 0  CheMed123_10.jpg          0.630541       toilet
# 1  CheMed123_13.jpg          0.426693  sports ball
# 2  CheMed123_13.jpg          0.415904  sports ball
# 3  CheMed123_13.jpg          0.279390  sports ball
# 4  CheMed123_17.jpg          0.654967       bottle
#
#                                     bbox_coordinates  \
# 0  [888.73681640625, 182.22438049316406, 1079.087...
# 1  [739.5655517578125, 545.6803588867188, 808.522...
# 2  [318.5856018066406, 395.181884765625, 382.6188...
# 3  [149.63067626953125, 546.4663696289062, 220.80...
# 4  [576.642822265625, 380.4325256347656, 606.6428...
#
#                             result_image_path       detection_time
# 0  ../data/detaction_results\CheMed123_10.jpg  2024-10-14 22:22:14
# 1  ../data/detaction_results\CheMed123_13.jpg  2024-10-14 22:22:16
# 2  ../data/detaction_results\CheMed123_13.jpg  2024-10-14 22:22:16
# 3  ../data/detaction_results\CheMed123_13.jpg  2024-10-14 22:22:16
# 4  ../data/detaction_results\CheMed123_17.jpg  2024-10-14 22:22:18

# %% [markdown]
# #### Insert Detected image result into a Postgres

# %%
# Import functions for database connection and inserting detection data
from database.db_image_insert import connect_db, insert_detection_data

# %% [markdown]
# #### Connect database

# %%
# Establish a connection to the database
connect_db()
# Out:
# <connection object at 0x000001D2982EA350; dsn: 'user=postgres password=xxx dbname=postgres host=localhost port=5432', closed: 0>

# %%
# Insert the detection data from the DataFrame into the database
insert_detection_data(df)
# Out:
# Data successfully inserted into PostgreSQL.

# %% [markdown]
# ---
# ## Image Detection and Database Insertion Summary
#
# ### Overview
# This task involves using a YOLO (You Only Look Once) object detection model to process images, extract detection results, and insert those results into a database for further analysis.
#
# ### Steps
#
# 1. **Import Libraries**: Necessary libraries for image processing, object detection, and database interaction are imported.
#
# 2. **Load YOLO Model**: The YOLO model is loaded for object detection tasks.
#
# 3. **Set Paths**: Paths for the input image folder and output detection results folder are defined.
#
# 4. **Process Images**:
#    - The images in the specified folder are processed using the loaded YOLO model to detect objects.
#    - Detection results are saved in a CSV file.
#
# 5. **Load Detection Results**: The detection results are loaded into a Pandas DataFrame from the CSV file for further manipulation or analysis.
#
# 6. **Database Connection**: A connection to the database is established to prepare for data insertion.
#
# 7. **Insert Data**: The detection data from the DataFrame is inserted into the database for persistent storage.
#
# ### Conclusion
# This workflow enables efficient object detection from images and ensures that the results are systematically stored in a database for future reference or analysis.
